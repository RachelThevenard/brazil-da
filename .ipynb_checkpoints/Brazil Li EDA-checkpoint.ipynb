# %%
# root file variable
f = "./data/"

# %%
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patheffects as pe
import numpy as np
from array import array

# %% [markdown]
# ###  Loading spatial data

# %%
shp = "shp/"

# %%
munic_fn = "BR_Municipios_2022/BR_Municipios_2022.shp"
munic = gpd.read_file(f + shp + munic_fn)

# %%
munic.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
uni_fn = "BR_UF_2022/BR_UF_2022.shp"
uni = gpd.read_file(f + shp + uni_fn)
uni['NM_REGIAO'] = uni['NM_REGIAO'].str.replace('\n', '')
uni['NM_REGIAO'] = uni['NM_REGIAO'].str.replace('Centro-oeste', 'Centro-Oeste')

# %%
uni.head()
# Out:
#   CD_UF      NM_UF SIGLA_UF NM_REGIAO     AREA_KM2  \
# 0    12       Acre       AC     Norte   164173.429
# 1    13   Amazonas       AM     Norte  1559255.881
# 2    15       Pará       PA     Norte  1245870.704
# 3    16      Amapá       AP     Norte   142470.762
# 4    17  Tocantins       TO     Norte   277423.627
#
#                                             geometry
# 0  POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...
# 1  POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...
# 2  MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...
# 3  MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...
# 4  POLYGON ((-48.24830 -13.19239, -48.24844 -13.1...

# %%
uni["NM_REGIAO"].values
# Out:
# array(['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste',
#        'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste',
#        'Nordeste', 'Nordeste', 'Nordeste', 'Sudeste', 'Sudeste',
#        'Sudeste', 'Sudeste', 'Sul', 'Sul', 'Sul', 'Centro-Oeste',
#        'Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste', 'Norte', 'Norte'],
#       dtype=object)

# %%
regiao = uni.dissolve("NM_REGIAO").reset_index()

# %%
regiao.head()
# Out:
#       NM_REGIAO                                           geometry CD_UF  \
# 0  Centro-Oeste  POLYGON ((-54.68763 -23.83257, -54.69158 -23.8...    50
# 1      Nordeste  MULTIPOLYGON (((-44.58770 -2.23098, -44.58787 ...    21
# 2         Norte  MULTIPOLYGON (((-62.61374 -13.01363, -62.61907...    12
# 3       Sudeste  MULTIPOLYGON (((-48.03773 -25.35624, -48.03747...    31
# 4           Sul  MULTIPOLYGON (((-51.74802 -31.86998, -51.75479...    41
#
#                 NM_UF SIGLA_UF    AREA_KM2
# 0  Mato Grosso do Sul       MS  357142.082
# 1            Maranhão       MA  329651.496
# 2                Acre       AC  164173.429
# 3        Minas Gerais       MG  586513.983
# 4              Paraná       PR  199298.981

# %%
regiao.plot(column='NM_REGIAO', legend = True)
# Out:
# <AxesSubplot:>

# %%
br_fn = "BR_Pais_2022/BR_Pais_2022.shp"
br = gpd.read_file(f + shp + br_fn)

# %%
br.head()
# Out:
#   NM_PAIS     AREA_KM2                                           geometry
# 0  Brasil  8510417.771  MULTIPOLYGON (((-41.82601 -2.75727, -41.82171 ...

# %%
fig, ax = plt.subplots()

fig.subplots_adjust(right=0.8)
uni.plot(ax=ax, column="NM_REGIAO", legend=True)
munic.boundary.plot(ax=ax, linewidth = 0.5, color = "lightgray")
uni.boundary.plot(ax=ax, linewidth = 0.7, color= 'red')
br.boundary.plot(ax=ax, color='black')


plt.show()

# %%
mining_con_fn = "Brazil_mining_concessions/Brazil_mining_concessions.shp"
mining_con = gpd.read_file(f + shp + mining_con_fn)

# %%
mining_con.head()
# Out:
#    objectid                                      id  numero   ano  area_ha  \
# 0    203664  {091DBD66-885B-4F55-B476-A79C26B28246}  880147  1979   9800.0
# 1    203665  {3AE579FD-F0B7-4CA1-A18B-77E3F9C942B6}  880954  1985     50.0
# 2    203666  {BE2987A8-9D73-4D89-BF84-F4A1796CA491}  880468  1987  10000.0
# 3    203667  {720585BA-00BA-4261-A81D-224733E91402}  880469  1987  10000.0
# 4    203668  {734009C7-11D1-4D7F-9BB3-551A280D136E}  880002  1992     50.0
#
#                        fase  \
# 0   AUTORIZAÇÃO DE PESQUISA
# 1        CONCESSÃO DE LAVRA
# 2  REQUERIMENTO DE PESQUISA
# 3  REQUERIMENTO DE PESQUISA
# 4        CONCESSÃO DE LAVRA
#
#                                           ult_evento  \
# 0  290 - AUT PESQ/RELATORIO PESQ FINAL APRESENTAD...
# 1  440 - CONC LAV/ROTULO ÁGUA MINERAL APROVADO PU...
# 2  619 - REQ PESQ/PROCESSO SITUADO EM ÁREA INDÍGE...
# 3  619 - REQ PESQ/PROCESSO SITUADO EM ÁREA INDÍGE...
# 4  473 - CONC LAV/CUMPRIMENTO EXIGÊNCIA PROTOCOLI...
#
#                                          nome          subs            uso  \
# 0                       MINERAÇÃO IGUAPO LTDA    WOLFRAMITA  NÃO INFORMADO
# 1  Verona Mineração Indústria e Comércio Ltda  ÁGUA MINERAL  NÃO INFORMADO
# 2                     EXPLORER MINERAÇÃO LTDA         PRATA  NÃO INFORMADO
# 3                     EXPLORER MINERAÇÃO LTDA         PRATA  NÃO INFORMADO
# 4    EMPRESA DE ÁGUA MINERAL MONTE MÁRIO LTDA  ÁGUA MINERAL  NÃO INFORMADO
#
#    uf          status                                globalid    shape_Leng  \
# 0  AC     Exploration  {3D22252D-8F73-4596-A873-28DDF32A2B4D}  40944.915251
# 1  AC    Exploitation  {C536EEAC-DBC8-4400-9215-711BA3AB4829}   3053.873800
# 2  AC  In application  {2A1BDF1F-9E85-4249-83A7-FA6AA7F64BF9}  40467.951019
# 3  AM  In application  {6F3D16D0-CBE8-4698-888F-E6E1894F9ECE}  40467.951709
# 4  AC    Exploitation  {54E93E61-A6FC-42E0-8115-687319922E68}   3059.315900
#
#      shape_Area                                           geometry
# 0  1.003029e+08  POLYGON Z ((-73.65896 -7.36562 0.00000, -73.65...
# 1  5.192398e+05  POLYGON Z ((-67.73617 -10.13297 0.00000, -67.7...
# 2  1.023523e+08  POLYGON Z ((-73.33693 -7.36168 0.00000, -73.33...
# 3  1.023523e+08  POLYGON Z ((-73.33693 -7.36168 0.00000, -73.24...
# 4  5.188346e+05  POLYGON Z ((-67.80873 -10.00312 0.00000, -67.8...

# %%
mineral_res_url = r"https://geoportal.sgb.gov.br/server/rest/services/geologia/ocorrencias/MapServer"
mineral_res = gpd.read_file(mineral_res_url)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsimem/66650a4f467b408faa658f92012f7d00' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [285], in <cell line: 2>()
#       1 mineral_res_url = r"https://geoportal.sgb.gov.br/server/rest/services/geologia/ocorrencias/MapServer"
# ----> 2 mineral_res = gpd.read_file(mineral_res_url)
#
# File ~\anaconda3\envs\pandas_geopandas\lib\site-packages\geopandas\io\file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     198     reader = fiona.open
#     200 with fiona_env():
# --> 201     with reader(path_or_bytes, **kwargs) as features:
#     202
#     203         # In a future Fiona release the crs attribute of features will
#     204         # no longer be a dict, but will behave like a dict. So this should
#     205         # be forwards compatible
#     206         crs = (
#     207             features.crs["init"]
#     208             if features.crs and "init" in features.crs
#     209             else features.crs_wkt
#     210         )
#     212         # handle loading the bounding box
#
# File ~\anaconda3\envs\pandas_geopandas\lib\site-packages\fiona\collection.py:555, in BytesCollection.__init__(self, bytesbuf, **kwds)
#     552 self.virtual_file = buffer_to_virtual_file(self.bytesbuf, ext=ext)
#     554 # Instantiate the parent class.
# --> 555 super(BytesCollection, self).__init__(self.virtual_file, vsi=filetype, **kwds)
#
# File ~\anaconda3\envs\pandas_geopandas\lib\site-packages\fiona\collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160 if self.mode == 'r':
#     161     self.session = Session()
# --> 162     self.session.start(self, **kwargs)
#     163 elif self.mode in ('a', 'w'):
#     164     self.session = WritingSession()
#
# File fiona\ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona\_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: '/vsimem/66650a4f467b408faa658f92012f7d00' not recognized as a supported file format.

# %%
terr_indig_fn = "Indigenas_Quilombolas/Territ┬ório Ind┬░gena.shp"
terr_indig = gpd.read_file(f + shp + terr_indig_fn)

# %%
terr_quilo_fn = "Indigenas_Quilombolas/Territ┬ório Quilombola.shp"
terr_quilo = gpd.read_file(f + shp + terr_quilo_fn)

# %%
fig, ax = plt.subplots()

terr_indig.plot(ax=ax, color="grey")
terr_quilo.plot(ax=ax, color="red")
mining_con.plot(ax=ax, marker='*')
br.boundary.plot(ax=ax, color='black')

plt.show()

# %% [markdown]
# ### Loading tables

# %%
# data directory variables

# 1_General
g = '1_General_xls' + '/'
# Work / Income
w = '2_Work_Income_xls' + '/'
# Violence
v = '5_Violence_xls' + '/'

# %%
df_race_fn = f + 'Tabela_02_Pop_resid_por_cor_ou_raca_e_pessoas_indigenas_2022_BR_GR.xlsx'
col_names = ['Grandes Regiões', 'Cód.', 'Total', 'a_Branca', 'a_Preta', 'a_Amarela', 'a_Parda', 'a_Indígena', 'a_Ignorados', 'p_Branca', 'p_Preta', 'p_Amarela', 'p_Parda', 'p_Indígena', 'Absoluto', 'Percentual']
df_race = pd.read_excel(df_race_fn, names=col_names, skiprows=8)[:6]

# %%
# Absolute and percentage race data by Grand Regions
# join w: brazil layer, uni -> region
# remove Região from Grand Region column
df_race = df_race.replace('Região ', '', regex=True)
df_race
# Out:
#   Grandes Regiões  Cód.           Total    a_Branca     a_Preta  a_Amarela  \
# 0          Brasil  76.0    203 080 756   88252121.0  20656458.0   850130.0
# 1           Norte   1.0     17 355 778    3598439.0   1530568.0    29467.0
# 2        Nordeste   2.0     54 657 621   14571416.0   7126868.0    68749.0
# 3         Sudeste   3.0     84 840 113   42318768.0   9003372.0   570852.0
# 4             Sul   4.0     29 937 706   21729713.0   1505526.0   120838.0
# 5    Centro-Oeste   5.0     16 289 538    6033785.0   1490124.0    60224.0
#
#       a_Parda  a_Indígena a_Ignorados   p_Branca    p_Preta  p_Amarela  \
# 0  92083286.0   1227642.0     11 119   43.459043  10.172106   0.418640
# 1  11654993.0    539821.0      2 490   20.736353   8.820046   0.169806
# 2  32559243.0    327725.0      3 620   26.661206  13.039975   0.125790
# 3  32833389.0    109934.0      3 798   49.882846  10.612639   0.672886
# 4   6499382.0     81478.0         769  72.584958   5.028991   0.403642
# 5   8536279.0    168684.0         442  37.041865   9.147985   0.369720
#
#      p_Parda  p_Indígena   Absoluto  Percentual
# 0  45.345669    0.604542  1694836.0    0.834563
# 1  67.163024    3.110771   753780.0    4.343107
# 2  59.573393    0.599636   529128.0    0.968077
# 3  38.702045    0.129584   123434.0    0.145490
# 4  21.710244    0.272165    88341.0    0.295083
# 5  52.404866    1.035564   200153.0    1.228721

# %%
df_race['Grandes Regiões'].values
# Out:
# array(['Brasil', 'Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'],
#       dtype=object)

# %%
regiao_race = pd.merge(regiao, df_race, left_on="NM_REGIAO", right_on="Grandes Regiões")
regiao_race = regiao_race.drop(['CD_UF', 'NM_UF', 'SIGLA_UF', 'AREA_KM2'], axis=1)
regiao_race
# Out:
#                                             geometry Grandes Regiões  Cód.  \
# 0  POLYGON ((-54.68763 -23.83257, -54.69158 -23.8...    Centro-Oeste   5.0
# 1  MULTIPOLYGON (((-44.58770 -2.23098, -44.58787 ...        Nordeste   2.0
# 2  MULTIPOLYGON (((-62.61374 -13.01363, -62.61907...           Norte   1.0
# 3  MULTIPOLYGON (((-48.03773 -25.35624, -48.03747...         Sudeste   3.0
# 4  MULTIPOLYGON (((-51.74802 -31.86998, -51.75479...             Sul   4.0
#
#            Total    a_Branca    a_Preta  a_Amarela     a_Parda  a_Indígena  \
# 0    16 289 538    6033785.0  1490124.0    60224.0   8536279.0    168684.0
# 1    54 657 621   14571416.0  7126868.0    68749.0  32559243.0    327725.0
# 2    17 355 778    3598439.0  1530568.0    29467.0  11654993.0    539821.0
# 3    84 840 113   42318768.0  9003372.0   570852.0  32833389.0    109934.0
# 4    29 937 706   21729713.0  1505526.0   120838.0   6499382.0     81478.0
#
#   a_Ignorados   p_Branca    p_Preta  p_Amarela    p_Parda  p_Indígena  \
# 0         442  37.041865   9.147985   0.369720  52.404866    1.035564
# 1      3 620   26.661206  13.039975   0.125790  59.573393    0.599636
# 2      2 490   20.736353   8.820046   0.169806  67.163024    3.110771
# 3      3 798   49.882846  10.612639   0.672886  38.702045    0.129584
# 4         769  72.584958   5.028991   0.403642  21.710244    0.272165
#
#    Absoluto  Percentual
# 0  200153.0    1.228721
# 1  529128.0    0.968077
# 2  753780.0    4.343107
# 3  123434.0    0.145490
# 4   88341.0    0.295083

# %%
fig, ((ax1, ax2, ax3)) = plt.subplots(1,3, figsize=(10, 5))
# Normalize color scale to range 0-100
vmin, vmax = 0, 75
norm = mcolors.Normalize(vmin=vmin, vmax=vmax)

fig.subplots_adjust(right=0.8)

regiao_race.plot(ax=ax1, column='p_Branca', cmap='plasma_r', norm=norm)
regiao_race.plot(ax=ax2, column='p_Preta', cmap='plasma_r', norm=norm)
regiao_race.plot(ax=ax3, column='p_Parda', cmap='plasma_r', norm=norm)

# Set titles for each subplot
ax1.set_title('Percentage White')
ax2.set_title('Percentage Black')
ax3.set_title('Percentage Parda')

# Add colorbar
sm = plt.cm.ScalarMappable(cmap='plasma_r', norm=norm)
sm._A = []
cbar_ax = fig.add_axes([0.85, 0.15, 0.03, 0.7])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.set_label('Percentage')

plt.show()

# %%
regiao_maj_race = regiao_race
regiao_maj_race["Max (%)"] = regiao_maj_race[['p_Branca', 'p_Preta', 'p_Parda']].max(axis=1).round(2)
regiao_maj_race["Maj Race"] = regiao_maj_race[['p_Branca', 'p_Preta', 'p_Parda']].idxmax(axis=1).str.replace('p_', '')
regiao_maj_race["coords"]= regiao_maj_race["geometry"].apply(lambda x: x.representative_point().coords[:])
regiao_race["coords"] = [coords[0] for coords in regiao_race["coords"]]

# %%
# Majority race in major regions of Brazil
regiao_maj_race.plot(column='Maj Race', legend=True)
plt.title("Majority race (%) in major regions of Brazil")
for idx, row in regiao_maj_race.iterrows():   
    plt.annotate(text=str(row['Max (%)']) + ' %', xy=row['coords'], horizontalalignment='center', color='black', path_effects=[pe.withStroke(linewidth=4, foreground="white")])

# %%
uni_race = pd.merge(uni, df_race, left_on="NM_REGIAO", right_on="Grandes Regiões")

# %%
uni_race
# Out:
#    CD_UF                NM_UF SIGLA_UF     NM_REGIAO     AREA_KM2  \
# 0     12                 Acre       AC         Norte   164173.429
# 1     13             Amazonas       AM         Norte  1559255.881
# 2     15                 Pará       PA         Norte  1245870.704
# 3     16                Amapá       AP         Norte   142470.762
# 4     17            Tocantins       TO         Norte   277423.627
# 5     11             Rondônia       RO         Norte   237754.172
# 6     14              Roraima       RR         Norte   223644.530
# 7     21             Maranhão       MA      Nordeste   329651.496
# 8     22                Piauí       PI      Nordeste   251755.481
# 9     23                Ceará       CE      Nordeste   148894.447
# 10    24  Rio Grande do Norte       RN      Nordeste    52809.599
# 11    25              Paraíba       PB      Nordeste    56467.242
# 12    26           Pernambuco       PE      Nordeste    98067.877
# 13    27              Alagoas       AL      Nordeste    27830.661
# 14    28              Sergipe       SE      Nordeste    21938.188
# 15    29                Bahia       BA      Nordeste   564760.429
# 16    31         Minas Gerais       MG       Sudeste   586513.983
# 17    32       Espírito Santo       ES       Sudeste    46074.448
# 18    33       Rio de Janeiro       RJ       Sudeste    43750.425
# 19    35            São Paulo       SP       Sudeste   248219.485
# 20    41               Paraná       PR           Sul   199298.981
# 21    42       Santa Catarina       SC           Sul    95730.690
# 22    43    Rio Grande do Sul       RS           Sul   281707.151
# 23    50   Mato Grosso do Sul       MS  Centro-Oeste   357142.082
# 24    51          Mato Grosso       MT  Centro-Oeste   903208.361
# 25    52                Goiás       GO  Centro-Oeste   340242.859
# 26    53     Distrito Federal       DF  Centro-Oeste     5760.784
#
#                                              geometry Grandes Regiões  Cód.  \
# 0   POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...           Norte   1.0
# 1   POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...           Norte   1.0
# 2   MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...           Norte   1.0
# 3   MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...           Norte   1.0
# 4   POLYGON ((-48.24830 -13.19239, -48.24844 -13.1...           Norte   1.0
# 5   POLYGON ((-62.60021 -13.01675, -62.59999 -13.0...           Norte   1.0
# 6   POLYGON ((-60.12972 4.50843, -60.12960 4.50826...           Norte   1.0
# 7   MULTIPOLYGON (((-44.58680 -2.23341, -44.58696 ...        Nordeste   2.0
# 8   POLYGON ((-42.47034 -3.48377, -42.46126 -3.484...        Nordeste   2.0
# 9   POLYGON ((-37.87162 -4.36640, -37.87109 -4.367...        Nordeste   2.0
# 10  MULTIPOLYGON (((-35.18728 -5.78987, -35.18707 ...        Nordeste   2.0
# 11  MULTIPOLYGON (((-34.79580 -7.17500, -34.79578 ...        Nordeste   2.0
# 12  MULTIPOLYGON (((-35.04823 -8.60936, -35.04756 ...        Nordeste   2.0
# 13  MULTIPOLYGON (((-35.28700 -9.14489, -35.28699 ...        Nordeste   2.0
# 14  MULTIPOLYGON (((-37.01203 -10.92784, -37.01267...        Nordeste   2.0
# 15  MULTIPOLYGON (((-39.26447 -8.61413, -39.26341 ...        Nordeste   2.0
# 16  POLYGON ((-42.51148 -14.98627, -42.50964 -14.9...         Sudeste   3.0
# 26  37.041865   9.147985   0.369720  52.404866    1.035564  200153.0
#
#     Percentual
# 0     4.343107
# 1     4.343107
# 2     4.343107
# 3     4.343107
# 4     4.343107
# 5     4.343107
# 6     4.343107
# 7     0.968077
# 8     0.968077
# 9     0.968077
# 10    0.968077
# 11    0.968077
# 12    0.968077
# 13    0.968077
# 14    0.968077
# 15    0.968077
# 16    0.145490
# 17    0.145490
# 18    0.145490
# 19    0.145490
# 20    0.295083
# 21    0.295083
# 22    0.295083
# 23    1.228721
# 24    1.228721
# 25    1.228721
# 26    1.228721
#
# [27 rows x 22 columns]

# %%
uni_race.plot()
# Out:
# <AxesSubplot:>

# %%
uf_race = pd.merge(uni_race, df_race, left_on="NM_REGIAO", right_on="Grandes Regiões")
uf_race = uf_race.drop(['CD_UF', 'NM_UF', 'SIGLA_UF', 'AREA_KM2'], axis=1)
uf_race

# %%
col_names = ['Grandes Regiões e Unidades da Federação', 'Total (1 000 pessoas)', 'p_Branca', 'p_Preta', 'p_Parda', 'p_Preta ou parda']
g_pop_geo_fn = f + g + 'Tabela 1.1 (Pop_Geo).xls'
g_pop_geo = pd.read_excel(g_pop_geo_fn, names=col_names, skiprows=5).drop([33,34])

# %%
# General race table
# join w: brazil layer and uni -> federation
g_pop_geo.head()
# Out:
#   Grandes Regiões e Unidades da Federação  Total (1 000 pessoas)   p_Branca  \
# 0                                  Brasil          212650.323424  43.013008
# 1                                   Norte           18577.619045  17.652349
# 2                                Rondônia            1804.543005  30.216115
# 3                                    Acre             889.829002  15.587439
# 4                                Amazonas            4103.520007  14.343252
#
#     p_Preta    p_Parda  p_Preta ou parda
# 0  9.075108  46.979981         56.055089
# 1  7.473744  73.421972         80.895716
# 2  8.235032  60.920943         69.155975
# 3  6.046421  77.040416         83.086837
# 4  3.019257  80.135778         83.155035

# %%
# Histogram

# %%
col_names = ['Grupos de idade', 'Total (1 000 pessoas)', 'Branca', 'Preta', 'Parda', 'Preta ou parda', 'p_Branca', 'p_Preta', 'p_Parda', 'p_Preta ou parda']
g_pop_idad_fn = f + g + 'Tabela 1.2 (Pop_Idad).xls'
g_pop_idad = pd.read_excel(g_pop_idad_fn, names= col_names, skiprows=5).drop([18,19])

# %%
# General age table
g_pop_idad.head()
# Out:
#   Grupos de idade  Total (1 000 pessoas)        Branca         Preta  \
# 0           Total          212650.323424  91467.301523  19298.246299
# 1      0 a 4 anos           14657.283134   6520.813540    866.981466
# 2      5 a 9 anos           14643.442024   5804.819015   1008.174497
# 3    10 a 14 anos           14669.677206   5613.965491   1051.139251
# 4    15 a 19 anos           15412.473820   5902.892415   1342.827045
#
#           Parda  Preta ou parda   p_Branca   p_Preta    p_Parda  \
# 0  99903.081546   119201.327844  43.013008  9.075108  46.979981
# 1   7180.902621     8047.884087  44.488555  5.915022  48.992044
# 2   7716.325555     8724.500053  39.641083  6.884819  52.694753
# 3   7903.196648     8954.335899  38.269182  7.165388  53.874373
# 4   8045.635844     9388.462889  38.299448  8.712599  52.202106
#
#    p_Preta ou parda
# 0         56.055089
# 1         54.907066
# 2         59.579572
# 3         61.039761
# 4         60.914705

# %%
col_names = ['Sexo e grupos de idade', 'Total (1 000 pessoas)', 'p_Branca', 'p_Preta', 'p_Parda', 'p_Amarela', 'p_Indígena']
g_pop_sex_idad_fn = f + g + 'Tabela 1.3 (Por_Sex_Idad).xls'
g_por_sex_idad = pd.read_excel(g_pop_sex_idad_fn, names=col_names, skiprows=5).drop([4, 10,11,12])

# %%
# Age pyramid

# %%
# General sex and age table
g_por_sex_idad
# Out:
#   Sexo e grupos de idade  Total (1 000 pessoas)   p_Branca    p_Preta  \
# 0                 Brasil          212650.323424  43.013008   9.075108
# 1                   Sexo                    NaN        NaN        NaN
# 2                 Homens          103945.651228  42.205962   9.267844
# 3               Mulheres          108704.672196  43.784722   8.890809
# 5            0 a 14 anos           43970.402364  40.799258   6.655148
# 6           15 a 29 anos           49374.908919  39.039849   9.758097
# 7           30 a 49 anos           63913.639121  42.148885  10.198349
# 8           50 a 59 anos           24159.146011  45.967507   9.782967
# 9        60 anos ou mais           31232.227010  51.893737   8.556170
#
#      p_Parda  p_Amarela  p_Indígena
# 0  46.979981   0.594372    0.316586
# 1        NaN        NaN         NaN
# 2  47.621761   0.567255    0.317144
# 3  46.366297   0.620301    0.316053
# 5  51.854028   0.406746    0.261321
# 6  50.331710   0.504499    0.342176
# 7  46.699045   0.632909    0.307955
# 8  43.104890   0.758938    0.349318
# 9  38.391717   0.794441    0.346282

# %%
# Two sided bar graph

# %%
# Tabela 2.5 - Average usual real income from the main job of people 
# aged 14 or over, employed in the reference week and in formal 
# and informal occupations, by color or race, according to the 
# Major Regions, the Federation Units and the Municipalities of 
# the Capitals - Brazil - 2021
col_names = ['Grandes Regiões, Unidades da Federação e Municípios das Capitais', 'fi_Total', 'fi_Branca', 'fi_Preta', 'fi_Parda', 'fi_Preta ou parda', 'f_Total', 'f_Branca', 'f_Preta', 'f_Parda', 'f_Preta ou parda', 'i_Total', 'i_Branca', 'i_Preta', 'i_Parda', 'i_Preta ou parda']
w_rend_form_geo_fn = f + w + 'Tabela 2.5 (Rend_Form_Geo).xls'
w_rend_form_geo = pd.read_excel(w_rend_form_geo_fn, names=col_names, skiprows=5).drop(0)[:60]

# %%
# Average usual real income by race (R$)
# join w: brazil layer, uni -> region, and uni -> federation
w_rend_form_geo
# Out:
#    Grandes Regiões, Unidades da Federação e Municípios das Capitais  \
# 1                                              Brasil
# 2                                               Norte
# 3                                            Rondônia
# 4                                         Porto Velho
# 5                                                Acre
# 6                                          Rio Branco
# 7                                            Amazonas
# 8                                              Manaus
# 9                                             Roraima
# 10                                          Boa Vista
# 11                                               Pará
# 12                                              Belém
# 13                                              Amapá
# 14                                             Macapá
# 15                                          Tocantins
# 16                                             Palmas
# 17                                           Nordeste
# 18                                           Maranhão
# 19                                           São Luís
# 20                                              Piauí
# 21                                           Teresina
# 40  3031.486614  5293.896990  1346.524432  1582.049924       1511.339415
# 41  1909.741187  2860.824936  1225.537286  1322.023215       1295.692487
# 42  2566.584096  3761.650955  1386.315111  1543.966365       1502.808840
# 43  2217.319091  2892.749852  1533.753521  1385.311229       1415.453413
# 44  3031.710982  4111.464085  1574.575194  1551.445657       1556.733258
# 45  1862.333956  2046.903560  1454.260549  1385.965430       1398.370277
# 46  1794.433628  2084.211406  1643.926179  1287.590337       1333.130003
# 47  2741.128317  3038.190395  1258.037809  1749.538737       1636.398918
# 48  2036.240156  2135.877131  1484.080039  1717.980756       1671.216043
# 49  3368.527856  3791.904688  1355.934313  2595.144978       2004.303220
# 50  1843.635885  1969.424441  1283.319039  1420.564842       1383.716464
# 51  2576.635422  2833.346196  1727.625341  1598.368454       1641.916057
# 52  1833.063460  2157.311854  1574.198021  1693.837373       1674.919960
# 53  1678.135538  2041.450686  1409.555689  1412.880825       1412.441122
# 54  1878.788334  2289.283416  1558.559233  1474.582495       1487.048730
# 55  1954.694354  2361.409502  1606.346879  1840.774197       1799.507582
# 56  1949.283869  2785.256234  1898.598663  1564.478607       1655.199760
# 57  1703.155356  2011.774112  1394.800110  1597.214843       1568.031370
# 58  2254.397983  3087.231033  1597.506787  1844.182056       1815.637389
# 59  2232.430437  2472.364584  2069.758008  2106.599992       2099.158699
# 60  2232.430437  2472.364584  2069.758008  2106.599992       2099.158699

# %%
# Tabela 2.7 - Usual real average hourly earnings from the main job of 
# people aged 14 or over employed in the reference week, by level of 
# education, according to Major Regions and color or race - Brazil - 2021
col_names = ['Grandes Regiões e cor ou raça', 'Total', 'No education or incomplete elementary school', 'Complete primary or incomplete secondary education', 'Complete secondary education or incomplete higher education', 'Complete higher education']
w_rend_instr_geo_fn = f + w + 'Tabela 2.7 (Rend_Instr_Geo).xls'
w_rend_instr_geo = pd.read_excel(w_rend_instr_geo_fn, names=col_names, skiprows=8)[:34]

# %%
w_rend_instr_geo.head()
# Out:
#   Grandes Regiões e cor ou raça      Total  \
# 0                        Brasil  14.840625
# 1                         Norte  11.830414
# 2                      Nordeste  10.772563
# 3                       Sudeste  16.802356
# 4                           Sul  15.727937
#
#    No education or incomplete elementary school  \
# 0                                      7.939413
# 1                                      7.000307
# 2                                      5.723534
# 3                                      8.694465
# 4                                      9.893126
#
#    Complete primary or incomplete secondary education  \
# 0                                           8.845861
# 1                                           7.554057
# 2                                           6.857159
# 3                                           9.299735
# 4                                          10.449899
#
#    Complete secondary education or incomplete higher education  \
# 0                                          11.276763
# 1                                           9.489811
# 2                                           9.089682
# 3                                          11.928421
# 4                                          12.924177
#
#    Complete higher education
# 0                  30.924454
# 1                  27.570546
# 2                  26.559119
# 3                  33.276917
# 4                  28.625802

# %%
# Tabela 2.9 - Percentage distribution of the population, by classes of 
# percentage of people in increasing order of real monthly household 
# income per capita, and color or race, according to the Major Regions 
# and Federation Units - Brazil - 2021
w_rend_percent_geo_fn = f + w + 'Tabela 2.9 (Rend_Percent_10_Geo).xls'
w_rend_percent_geo = pd.read_excel(w_rend_percent_geo_fn, header=[3, 4])[:33]

# %%
w_rend_percent_geo.head()
# Out:
#   Unnamed: 0_level_0      Total                                      \
#   Unnamed: 0_level_1     Branca     Preta      Parda Preta ou parda
# 0                NaN        NaN       NaN        NaN            NaN
# 1             Brasil  43.018616  9.069717  46.979444      56.049161
# 2              Norte  17.654986  7.474430  73.418406      80.892836
# 3           Rondônia  30.216115  8.235032  60.920943      69.155975
# 4               Acre  15.589286  6.035291  77.049543      83.084834
#
#   Among the 10% with lowest income                                       \
#                             Branca      Preta      Parda Preta ou parda
# 0                              NaN        NaN        NaN            NaN
# 1                        24.993870   9.691766  64.397231      74.088997
# 2                        10.160639   6.729632  80.915616      87.645247
# 3                        21.807912  23.442970  54.506677      77.949647
# 4                         8.938424   4.533426  84.323390      88.856815
#
#   Among the 10% with highest income
#                              Branca     Preta      Parda Preta ou parda
# 0                               NaN       NaN        NaN            NaN
# 1                         70.518035  4.257801  23.469955      27.727756
# 2                         31.158451  6.542550  60.632850      67.175400
# 3                         41.074859  5.512513  52.675396      58.187909
# 4                         28.229582  5.619347  65.563637      71.182984

# %%
# Tabela 2.10 - Percentage distribution of the population, by Major 
# Regions and color or race, according to the percentage classes of 
# people in increasing order of real monthly household income per 
# capita - Brazil - 2021
w_rend_pecent_geo_fn = f + w + 'Tabela 2.10 (Rend_Pecent_Geo).xls'
w_rend_pecent_geo = pd.read_excel(w_rend_pecent_geo_fn, header=[3,4])[:22]

# %%
w_rend_pecent_geo.head()
# Out:
#     Unnamed: 0_level_0      Brasil                                         \
#     Unnamed: 0_level_1      Branca       Preta       Parda Preta ou parda
# 0                  NaN         NaN         NaN         NaN            NaN
# 1                Total  100.000000  100.000000  100.000000     100.000000
# 2              Até 10%    5.808273   10.682653   13.703429      13.214615
# 3  Mais de 10% até 20%    6.213344   11.778184   13.189561      12.961176
# 4  Mais de 20% até 30%    7.018586   13.000377   12.160454      12.296368
#
#         Norte                                           Nordeste  ...  \
#        Branca       Preta       Parda Preta ou parda      Branca  ...
# 0         NaN         NaN         NaN            NaN         NaN  ...
# 1  100.000000  100.000000  100.000000     100.000000  100.000000  ...
# 2    5.753218    9.000579   11.017539      10.831174    8.253965  ...
# 3    6.965077    9.095956   10.764313      10.610158    8.088779  ...
# 4    6.908485    8.489638   10.904073      10.680981    8.964598  ...
#
#       Sudeste                        Sul                          \
#         Parda Preta ou parda      Branca       Preta       Parda
# 0         NaN            NaN         NaN         NaN         NaN
# 1  100.000000     100.000000  100.000000  100.000000  100.000000
# 2   13.486285      13.389412    8.172543   14.532287   15.962387
# 3   12.882708      13.015725    8.447648   12.453808   15.006439
# 4   11.763753      11.796076    8.889351   10.975318   14.138742
#
#                  Centro-Oeste
#   Preta ou parda       Branca       Preta       Parda Preta ou parda
# 0            NaN          NaN         NaN         NaN            NaN
# 1     100.000000   100.000000  100.000000  100.000000     100.000000
# 2      15.705857     7.386127   10.591321   11.529796      11.403665
# 3      14.548550     6.699056   12.291552   11.625932      11.715391
# 4      13.571290     7.544739   11.564494   11.305976      11.340721
#
# [5 rows x 25 columns]

# %%
# Tabela 5.3 - Percentage of students aged 13 to 17 who did not attend 
# school due to lack of security on the home-school route or at school 
# in the 30 days prior to the survey, by color or race, according to the 
# Major Regions and Federation Units - Brazil - 2019
col_names = ['Grandes Regiões e Unidades da Federação', 'Total', 'Branca', 'Preta', 'Parda', 'Preta ou parda']
v_violdesloc_geo_fn = f + v + 'Tabela 5.3 (ViolDesloc_Geo).xls'
v_violdesloc_geo = pd.read_excel(v_violdesloc_geo_fn, names=col_names, skiprows=7)[:33]

# %%
v_violdesloc_geo.head()
# Out:
#   Grandes Regiões e Unidades da Federação      Total     Branca      Preta  \
# 0                                  Brasil  16.637038  15.527353  19.756005
# 1                                   Norte  18.047943  19.452408  18.687123
# 2                                Rondônia  15.407923  15.665485  18.735959
# 3                                    Acre  16.282186  14.668995  19.155489
# 4                                Amazonas  19.796101  18.419304  14.398671
#
#        Parda  Preta ou parda
# 0  16.297427       17.126622
# 1  16.825446       17.120422
# 2  13.560016       14.506509
# 3  16.345142       16.814996
# 4  19.241150       18.692305

# %%
# Tabela 5.4 - Percentage of schoolchildren aged 13 to 17 who 
# were involved in a fight in which someone used a sharp weapon in the 
# 30 days prior to the survey, by color or race, according to the 
# administrative dependency of the school, the Major Regions and the 
# Federation Units - Brazil - 2019

col_names = ['Dependência administrativa da escola, Grandes Regiões e Unidades da Federação', 'Total', 'Branca', 'Preta', 'Parda', 'Preta ou parda']
v_violarma_geo_fn = f + v + 'Tabela 5.4 (ViolArma_Geo).xls'
v_violarma_geo = pd.read_excel(v_violarma_geo_fn, names=col_names, skiprows=7)[:37]

# %%
v_violarma_geo.head()
# Out:
#   Dependência administrativa da escola, Grandes Regiões e Unidades da Federação  \
# 0                                             Brasil
# 1                         Dependência administrativa
# 2                                            Pública
# 3                                            Privada
# 4            Grandes Regiões e Unidades da Federação
#
#       Total    Branca     Preta     Parda  Preta ou parda
# 0  4.811240  3.995054  7.257405  4.520183        5.176367
# 1       NaN       NaN       NaN       NaN             NaN
# 2  5.123814  4.483815  7.433845  4.662796        5.339809
# 3  2.970560  2.322826  5.216285  3.268877        3.652371
# 4       NaN       NaN       NaN       NaN             NaN

# %%
# Tabela 5.6 - Rate of deaths from undetermined causes in relation to the 
# total number of deaths from external causes, by color or race, according 
# to the Major Regions and Federation Units - Brazil - 2020

col_names = ['Grandes Regiões e Unidades da Federação', 'Total', 'Branca', 'Preta', 'Parda', 'Preta ou parda']
v_tx_obit_geo_fn = f + v + 'Tabela 5.6 (Tx_Obit_Geo).xls'
v_tx_obit_geo = pd.read_excel(v_tx_obit_geo_fn, names=col_names, skiprows=5)[:33]

# %%
v_tx_obit_geo.head()
# Out:
#   Grandes Regiões e Unidades da Federação     Total     Branca      Preta  \
# 0                                  Brasil  9.612567  10.940366  10.405889
# 1                                   Norte  3.934791   4.567600   5.255474
# 2                                Rondônia  6.168360   5.922551   6.097561
# 3                                    Acre  2.516779   0.000000   0.000000
# 4                                Amazonas  1.317716   1.388889   2.777778
#
#       Parda  Preta ou parda
# 0  8.497457        8.709956
# 1  3.643955        3.742315
# 2  6.309524        6.290672
# 3  2.083333        2.044990
# 4  1.338091        1.360843

# %%
# Tabela 5.7 - Proportion of people aged 18 or over who suffered violence 
# in the 12 months prior to the survey, by color or race, according to sex, 
# age groups and level of education - Brazil - 2019

col_names = ['Sexo, grupos de idade e nível de instrução', 'Total', 'Branca', 'Preta', 'Parda', 'Preta ou parda']
v_pop_viol_fn = f + v + 'Tabela 5.7 (Pop_Viol).xls'
v_pop_viol = pd.read_excel(v_pop_viol_fn, names=col_names, skiprows=6)[:14]

# %%
v_pop_viol
# Out:
#         Sexo, grupos de idade e nível de instrução      Total     Branca  \
# 0                                           Brasil  18.269734  16.621048
# 1                                             Sexo        NaN        NaN
# 2                                            Homem  17.011185  15.029427
# 3                                           Mulher  19.378571  17.978808
# 4                                  Grupos de idade        NaN        NaN
# 5                                     18 a 29 anos  27.002583  25.087929
# 6                                     30 a 39 anos  20.433959  18.998972
# 7                                     40 a 59 anos  16.545966  15.739012
# 8                                  60 anos ou mais  10.051948   9.483438
# 9                               Nível de instrução        NaN        NaN
# 10       Sem escolaridade a fundamental incompleto  15.347523  13.608767
# 11  Fundamental completo a ensino médio incompleto  20.708239  17.325540
# 12     Ensino médio completo a superior incompleto  19.936168  18.179707
# 13                               Superior completo  18.777049  17.597335
#
#         Preta      Parda  Preta ou parda
# 0   20.584955  19.293324       19.561360
# 1         NaN        NaN             NaN
# 2   19.802281  18.278510       18.593606
# 3   21.284678  20.208269       20.432349
# 4         NaN        NaN             NaN
# 5   32.767496  27.112278       28.239788
# 6   22.167083  21.350258       21.513206
# 7   17.433056  17.033079       17.118643
# 8   10.135692  10.715241       10.590282
# 9         NaN        NaN             NaN
# 10  17.919890  15.892120       16.301923
# 11  22.044328  22.878971       22.705071
# 12  24.121222  20.691983       21.412628
# 13  16.488071  22.334231       21.057058

# %% [markdown]
# ###  Loading spatial data

# %%
shp = "shp/"

# %%
munic_fn = "BR_Municipios_2022/BR_Municipios_2022.shp"
munic = gpd.read_file(f + shp + munic_fn)

# %%
munic.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...

# %%
uni_fn = "BR_UF_2022/BR_UF_2022.shp"
uni = gpd.read_file(f + shp + uni_fn)

# %%
uni.head()
# Out:
#   CD_UF      NM_UF SIGLA_UF NM_REGIAO     AREA_KM2  \
# 0    12       Acre       AC     Norte   164173.429
# 1    13   Amazonas       AM     Norte  1559255.881
# 2    15       Pará       PA     Norte  1245870.704
# 3    16      Amapá       AP     Norte   142470.762
# 4    17  Tocantins       TO     Norte   277423.627
#
#                                             geometry
# 0  POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...
# 1  POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...
# 2  MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...
# 3  MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...
# 4  POLYGON ((-48.24830 -13.19239, -48.24844 -13.1...

# %%
br_fn = "BR_Pais_2022/BR_Pais_2022.shp"
br = gpd.read_file(f + shp + br_fn)

# %%
br.head()
# Out:
#   NM_PAIS     AREA_KM2                                           geometry
# 0  Brasil  8510417.771  MULTIPOLYGON (((-41.82601 -2.75727, -41.82171 ...

# %%
fig, ax = plt.subplots()

uni.plot(ax=ax, column="NM_REGIAO", legend=True)
munic.boundary.plot(ax=ax, linewidth = 0.5, color = "lightgray")
uni.boundary.plot(ax=ax, linewidth = 0.7, color= 'red')
br.boundary.plot(ax=ax, color='black')


plt.show()

# %%
uni.plot(column="NM_REGIAO", legend=True)
# Out:
# <AxesSubplot:>

# %%
microregio_fn = "BR_Microrregioes_2022/BR_Microrregioes_2022.shp"
microregio = gpd.read_file(f + shp + microregio_fn)

# %%
microregio.head()
# Out:
#   CD_MICRO          NM_MICRO SIGLA_UF   AREA_KM2  \
# 0    11001       Porto Velho       RO  65658.650
# 1    11002     Guajará-Mirim       RO  40792.646
# 2    11003         Ariquemes       RO  24333.565
# 3    11004         Ji-Paraná       RO  25090.399
# 4    11005  Alvorada D'Oeste       RO  15965.819
#
#                                             geometry
# 0  POLYGON ((-63.52430 -10.24964, -63.52192 -10.2...
# 1  POLYGON ((-63.68476 -12.45306, -63.68567 -12.4...
# 2  POLYGON ((-62.67077 -10.28778, -62.69302 -10.3...
# 3  POLYGON ((-62.15923 -11.06775, -62.16103 -11.0...
# 4  POLYGON ((-63.19546 -11.10339, -63.19459 -11.1...

# %%
mesoregio_fn = "BR_Mesorregioes_2022/BR_Mesorregioes_2022.shp"
mesoregio = gpd.read_file(f + shp + mesoregio_fn)

# %%
mesoregio.head()
# Out:
#   CD_MESO            NM_MESO SIGLA_UF    AREA_KM2  \
# 0    1101    Madeira-Guaporé       RO  106451.296
# 1    1102  Leste Rondoniense       RO  131302.876
# 2    1201      Vale do Juruá       AC   85452.353
# 3    1202       Vale do Acre       AC   78721.076
# 4    1301   Norte Amazonense       AM  404888.525
#
#                                             geometry
# 0  POLYGON ((-63.68476 -12.45306, -63.68567 -12.4...
# 1  POLYGON ((-62.41771 -13.11894, -62.41902 -13.1...
# 2  POLYGON ((-73.12803 -8.77124, -73.12998 -8.769...
# 3  POLYGON ((-67.97684 -9.35273, -67.88121 -9.396...
# 4  POLYGON ((-66.00136 -2.14483, -66.01132 -2.141...

# %%
imediatas_fn = "BR_RG_Imediatas_2022/BR_RG_Imediatas_2022.shp"
imediatas = gpd.read_file(f + shp + imediatas_fn)

# %%
imediatas.head()
# Out:
#    CD_RGI       NM_RGI SIGLA_UF   AREA_KM2  \
# 0  110001  Porto Velho       RO  79943.767
# 1  110002    Ariquemes       RO  23260.950
# 2  110003         Jaru       RO  21853.300
# 3  110004    Ji-Paraná       RO  45080.055
# 4  110005       Cacoal       RO  36166.460
#
#                                             geometry
# 0  POLYGON ((-65.38150 -10.42907, -65.38013 -10.4...
# 1  POLYGON ((-63.09956 -9.48078, -63.06119 -9.471...
# 2  POLYGON ((-62.42317 -9.80583, -62.42287 -9.804...
# 3  POLYGON ((-62.52526 -10.70947, -62.49998 -10.6...
# 4  POLYGON ((-61.74230 -11.33348, -61.74303 -11.3...

# %%
intermediarias_fn = "BR_RG_Intermediarias_2022/BR_RG_Intermediarias_2022.shp"
intermediarias = gpd.read_file(f + shp + intermediarias_fn)

# %%
intermediarias.head()
# Out:
#   CD_RGINT         NM_RGINT SIGLA_UF    AREA_KM2  \
# 0     1101      Porto Velho       RO  125058.017
# 1     1102        Ji-Paraná       RO  112696.154
# 2     1201       Rio Branco       AC   78721.076
# 3     1202  Cruzeiro do Sul       AC   85452.353
# 4     1301           Manaus       AM  566706.115
#
#                                             geometry
# 0  POLYGON ((-61.95442 -9.94968, -61.95552 -9.950...
# 1  POLYGON ((-60.91898 -13.54833, -60.91651 -13.5...
# 2  POLYGON ((-67.97684 -9.35273, -67.88121 -9.396...
# 3  POLYGON ((-73.12803 -8.77124, -73.12998 -8.769...
# 4  POLYGON ((-61.29357 -4.71189, -61.30860 -4.749...

# %%
regioes_fn = "RG2017_regioesgeograficas2017.shp"
regioes = gpd.read_file(f + shp + regioes_fn)

# %%
regioes.head()
# Out:
#    OBJECTID            NOME CD_GEOCODI  UF     rgi  \
# 0         1        Brasília    5300108  53  530001
# 1         2   Vila Propício    5222302  52  520018
# 2         3        Vila Boa    5222203  52  520022
# 3         4  Vicentinópolis    5222054  52  520009
# 4         5      Vianópolis    5222005  52  520002
#
#                      nome_rgi rgint                        nome_rgint  \
# 0            Distrito Federal  5301                  Distrito Federal
# 1  Ceres - Rialma - Goianésia  5205                Porangatu - Uruaçu
# 2             Flores de Goiás  5206  Luziânia - Águas Lindas de Goiás
# 3                 Piracanjuba  5202                         Itumbiara
# 4                    Anápolis  5201                           Goiânia
#
#                                             geometry
# 0  POLYGON Z ((-48.23248 -15.78360 0.00000, -48.2...
# 1  POLYGON Z ((-48.86700 -15.09735 0.00000, -48.8...
# 2  POLYGON Z ((-46.97635 -14.93112 0.00000, -46.9...
# 3  POLYGON Z ((-49.90713 -17.61460 0.00000, -49.9...
# 4  POLYGON Z ((-48.58275 -16.94786 0.00000, -48.5...
